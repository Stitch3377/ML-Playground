# %% [markdown]
# # Finetuning an LLM to Generate Book Plots

# %% [markdown]
# ### Initial Setup

# %%
model_name = "distilgpt2"
device = "cuda"
dataset_path = "./goodreads_top100.csv"

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(model_name).to(device)

model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %% [markdown]
# ### Import a Dataset

# %%
import pandas as pd

df = pd.read_csv(dataset_path)
df
# Out:
#       Unnamed: 0           isbn  \
# 0              0  9780689830594
# 1              1  9780375704970
# 2              2  9780345446671
# 3              3  9780446403016
# 4              4  9780425198773
# ...          ...            ...
# 4395        4395  9781451648218
# 4396        4396  9781250826978
# 4397        4397  9781496737298
# 4398        4398  9780525619994
# 4399        4399  9780593239919
#
#                                                   title  \
# 0                                         Summer Story
# 1                                  The Lake of Darkness
# 2                        Beyond the Blue Event Horizon
# 3                                     St. Peter's Fair
# 4                                             Twice Shy
# ...                                                 ...
# 4395  Murder Your Employer: The McMasters Guide to H...
# 4396                                   System Collapse
# 4397                                 Georgie, All Along
# 4398                                     Sword Catcher
# 4399                                Poverty, by America
#
#                        series_title series_release_number          authors  \
# 0                     Brambly Hedge                     2     Jill Barklem
# 1                               NaN                   NaN     Ruth Rendell
# 2                      Heechee Saga                     2    Frederik Pohl
# 3     Chronicles of Brother Cadfael                     4     Ellis Peters
# 4                               NaN                   NaN     Dick Francis
# ...                             ...                   ...              ...
# 4395                            NaN                   NaN    Rupert Holmes
# 4396          The Murderbot Diaries                     7     Martha Wells
# 4397                            NaN                   NaN    Kate Clayborn
# 4398                  Sword Catcher                     1  Cassandra Clare
# 4399                            NaN                   NaN  Matthew Desmond
#
#                                  publisher language  \
# 0                                 Atheneum  English
# 1               Vintage Crime/Black Lizard  English
# 2                         Ballantine Books  English
# 3                         Mysterious Press  English
# 4                       G.P. Putnam's Sons  English
# ...                                    ...      ...
# 4395  Avid Reader Press / Simon & Schuster  English
# 4396        Tor Publishing Group/Tordotcom  English
# 4397                            Kensington  English
# 4398                         Del Rey Books  English
# 4399                                 Crown  English
#
#                                             description num_pages  \
# 0     It was such a hot summer. The sky was deep blu...        32
# 1     Martin Urban is a quiet bachelor with a comfor...       210
# 2     In Book Two of the Heechee Saga, Robinette Bro...       336
# 3     A pause in the civil war offers Shrewsbury's t...       217
# 4     A computerized horse-betting system falls into...       304
# ...                                                 ...       ...
# 4395  A devilish thriller with a killer concept: The...       389
# 4396  Everyone's favorite lethal SecUnit is back.\r\...       245
# 4397  A wise and witty new novel that echoes with ti...       340
# 4398  In the vibrant city-state of Castellane, the r...       624
# 4399  The Pulitzer Prize–winning, bestselling author...       284
#
#                      format  \
# 0                 Hardcover
# 1                 Paperback
# 2                 Paperback
# 3     Mass Market Paperback
# 4     Mass Market Paperback
# ...                     ...
# 4395              Hardcover
# 4396              Hardcover
# 4397              Paperback
# 4398              Hardcover
# 4399              Hardcover
#
#                                                  genres   publication_date  \
# 0     ['Picture Books', 'Childrens', 'Fiction', 'Ani...    January 1, 1980
# 1     ['Mystery', 'Fiction', 'Crime', 'Thriller', 'B...    January 1, 1980
# 2     ['Science Fiction', 'Fiction', 'Space Opera', ...    January 1, 1980
# 3     ['Mystery', 'Historical Fiction', 'Fiction', '...        May 1, 1981
# 4     ['Mystery', 'Fiction', 'Thriller', 'Crime', 'S...    January 1, 1981
# ...                                                 ...                ...
# 4395  ['Mystery', 'Fiction', 'Thriller', 'Mystery Th...  February 21, 2023
# 4396  ['Science Fiction', 'Fiction', 'Audiobook', 'A...  November 13, 2023
# 4397  ['Romance', 'Fiction', 'Contemporary', 'Contem...   January 24, 2023
# 4398  ['Fantasy', 'Romance', 'Adult', 'Young Adult',...   October 10, 2023
# 4399  ['Nonfiction', 'Politics', 'Sociology', 'Histo...     March 21, 2023
#
#       rating_score  num_ratings  num_reviews  current_readers  want_to_read  \
# 0             4.45       1017.0         74.0              7.0         512.0
# 1             3.76       1388.0        114.0             77.0         623.0
# 2             3.95      13307.0        339.0            181.0        3961.0
# 3             4.12      10493.0        593.0           1298.0        2502.0
# 4             3.92       4188.0        174.0            162.0         642.0
# ...            ...          ...          ...              ...           ...
# 4395          3.89      20992.0       3479.0           4033.0       84900.0
# 4396          4.24      26566.0       3479.0           3609.0       36600.0
# 4397          3.82      48031.0       6590.0           3180.0       76300.0
# 4398          3.84      14991.0       3523.0           4485.0      149000.0
# 4399          4.30      28248.0       4007.0           6021.0      133000.0
#
#       price                                                url
# 0      3.49  https://www.goodreads.com/book/show/421572.Sum...
# 1      4.99  https://www.goodreads.com/book/show/83394.The_...
# 2     11.99  https://www.goodreads.com/book/show/373399.Bey...
# 3      0.00  https://www.goodreads.com/book/show/751755.St_...
# 4      8.99  https://www.goodreads.com/book/show/103250.Twi...
# ...     ...                                                ...
# 4395  12.99  https://www.goodreads.com/book/show/61272658-m...
# 4396  11.99  https://www.goodreads.com/book/show/65211701-s...
# 4397   0.00  https://www.goodreads.com/book/show/60604190-g...
# 4398  14.99  https://www.goodreads.com/book/show/36679274-s...
# 4399  13.99  https://www.goodreads.com/book/show/61358638-p...
#
# [4400 rows x 20 columns]

# %%
df = df[:1000]
df
# Out:
#      Unnamed: 0           isbn  \
# 0             0  9780689830594
# 1             1  9780375704970
# 2             2  9780345446671
# 3             3  9780446403016
# 4             4  9780425198773
# ..          ...            ...
# 995         995  9783857911538
# 996         996  9781933397269
# 997         997  9780099742005
# 998         998  9780912333397
# 999         999  9780752853697
#
#                                                  title  \
# 0                                        Summer Story
# 1                                 The Lake of Darkness
# 2                       Beyond the Blue Event Horizon
# 3                                    St. Peter's Fair
# 4                                            Twice Shy
# ..                                                 ...
# 995                   Schweiz Ohne Armee?: Ein Palaver
# 996                             Death Of A Hollow Man
# 997                                       Total Recall
# 998  Around the World in 80 Days: Companion to the ...
# 999                              The Unadulterated Cat
#
#                       series_title series_release_number          authors  \
# 0                    Brambly Hedge                     2     Jill Barklem
# 1                              NaN                   NaN     Ruth Rendell
# 2                     Heechee Saga                     2    Frederik Pohl
# 3    Chronicles of Brother Cadfael                     4     Ellis Peters
# 4                              NaN                   NaN     Dick Francis
# ..                             ...                   ...              ...
# 995                            NaN                   NaN       Max Frisch
# 996        Chief Inspector Barnaby                     2  Caroline Graham
# 997                            NaN                   NaN    Piers Anthony
# 998                            NaN                   NaN    Michael Palin
# 999                            NaN                   NaN  Terry Pratchett
#
#                       publisher language  \
# 0                      Atheneum  English
# 1    Vintage Crime/Black Lizard  English
# 2              Ballantine Books  English
# 3              Mysterious Press  English
# 4            G.P. Putnam's Sons  English
# ..                          ...      ...
# 995               Limmat Verlag   German
# 996             Felony & Mayhem  English
# 997                 Arrow Books  English
# 998                   Bay Books  English
# 999                    Gollancz  English
#
#                                            description num_pages  \
# 0    It was such a hot summer. The sky was deep blu...        32
# 1    Martin Urban is a quiet bachelor with a comfor...       210
# 2    In Book Two of the Heechee Saga, Robinette Bro...       336
# 3    A pause in the civil war offers Shrewsbury's t...       217
# 4    A computerized horse-betting system falls into...       304
# ..                                                 ...       ...
# 995                                             German        93
# 996  Actors do love their dramas, and the members o...       306
# 997  Implanted with a synthetic memory, a man begin...       224
# 998  The British actor and humorist describes his e...       262
# 999  The Unadulterated Cat is becoming an endangere...       157
#
#                     format                                             genres  \
# 0                Hardcover  ['Picture Books', 'Childrens', 'Fiction', 'Ani...
# 1                Paperback  ['Mystery', 'Fiction', 'Crime', 'Thriller', 'B...
# 2                Paperback  ['Science Fiction', 'Fiction', 'Space Opera', ...
# 3    Mass Market Paperback  ['Mystery', 'Historical Fiction', 'Fiction', '...
# 4    Mass Market Paperback  ['Mystery', 'Fiction', 'Thriller', 'Crime', 'S...
# ..                     ...                                                ...
# 995              Hardcover                ['Nonfiction', 'Politics', 'Plays']
# 996              Paperback  ['Mystery', 'Fiction', 'Crime', 'Mystery Thril...
# 997              Paperback  ['Science Fiction', 'Fiction', 'Fantasy', 'Sci...
# 998              Paperback  ['Travel', 'Nonfiction', 'Audiobook', 'Adventu...
# 999              Hardcover  ['Humor', 'Fantasy', 'Fiction', 'Cats', 'Anima...
#
#      publication_date  rating_score  num_ratings  num_reviews  \
# 0     January 1, 1980          4.45       1017.0         74.0
# 1     January 1, 1980          3.76       1388.0        114.0
# 2     January 1, 1980          3.95      13307.0        339.0
# 3         May 1, 1981          4.12      10493.0        593.0
# 4     January 1, 1981          3.92       4188.0        174.0
# ..                ...           ...          ...          ...
# 995   January 1, 1989          3.68         68.0          4.0
# 996   January 1, 1989          3.87       3635.0        306.0
# 997   January 1, 1989          3.93       8684.0        106.0
# 998  February 1, 1990          4.03       7326.0        262.0
# 999   January 1, 1989          3.82       7095.0        411.0
#
#      current_readers  want_to_read  price  \
# 0                7.0         512.0   3.49
# 1               77.0         623.0   4.99
# 2              181.0        3961.0  11.99
# 3             1298.0        2502.0   0.00
# 4              162.0         642.0   8.99
# ..               ...           ...    ...
# 995              NaN          33.0    NaN
# 996            630.0        1759.0   1.99
# 997             22.0        2618.0    NaN
# 998            126.0        3859.0   5.99
# 999             60.0        4065.0  10.99
#
#                                                    url
# 0    https://www.goodreads.com/book/show/421572.Sum...
# 1    https://www.goodreads.com/book/show/83394.The_...
# 2    https://www.goodreads.com/book/show/373399.Bey...
# 3    https://www.goodreads.com/book/show/751755.St_...
# 4    https://www.goodreads.com/book/show/103250.Twi...
# ..                                                 ...
# 995  https://www.goodreads.com/book/show/6325183-sc...
# 996  https://www.goodreads.com/book/show/454571.Dea...
# 997  https://www.goodreads.com/book/show/15512.Tota...
# 998  https://www.goodreads.com/book/show/221304.Aro...
# 999  https://www.goodreads.com/book/show/34496.The_...
#
# [1000 rows x 20 columns]

# %% [markdown]
# ### Tokenize the Dataset

# %%
from datasets import Dataset

col_name = "description"

def map_dataset(batch):
    texts = [str(x) if x is not None else "" for x in batch[col_name]]
    return tokenizer(
        texts,
        truncation=True,
        max_length=128,
        return_overflowing_tokens=True,
    )


dataset = Dataset.from_pandas(df)
dataset = dataset.map(
    map_dataset,
    batched=True,
    batch_size=8,
    remove_columns=list(df.columns)
)
dataset = dataset.remove_columns(["overflow_to_sample_mapping"])
dataset = dataset.train_test_split(test_size=0.2)
dataset
# Out:
# Map: 100%|██████████| 1000/1000 [00:00<00:00, 2599.12 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 1414
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 354
#     })
# })

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)
data_collator
# Out:
# DataCollatorForLanguageModeling(tokenizer=GPT2TokenizerFast(name_or_path='distilgpt2', vocab_size=50257, model_max_length=1024, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<|endoftext|>', 'eos_token': '<|endoftext|>', 'unk_token': '<|endoftext|>', 'pad_token': '<|endoftext|>'}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	50256: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# }
# ), mlm=False, mlm_probability=0.15, mask_replace_prob=0.8, random_replace_prob=0.1, pad_to_multiple_of=None, tf_experimental_compile=False, return_tensors='pt', seed=None)

# %% [markdown]
# ### Training the Model
# (the output directory is not included in the repo as the files are quite large)

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir="./output/model",
    eval_strategy="epoch",
    learning_rate=2e-5,
    weight_decay=0.01,
    num_train_epochs=10,
)

trainer = Trainer(
    model=model,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    args=training_args,
    data_collator=data_collator,
)

trainer.train()
# Out:
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='1770' max='1770' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1770/1770 04:10, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>4.151721</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>4.045654</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.141300</td>
#       <td>4.027944</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.141300</td>
#       <td>4.023036</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.141300</td>
#       <td>4.029499</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.809600</td>
#       <td>4.034629</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.809600</td>
#       <td>4.036207</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.809600</td>
#       <td>4.039639</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.686300</td>
#       <td>4.042989</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.686300</td>
#       <td>4.043684</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1770, training_loss=3.844014933957892, metrics={'train_runtime': 251.1512, 'train_samples_per_second': 56.301, 'train_steps_per_second': 7.048, 'total_flos': 461419440832512.0, 'train_loss': 3.844014933957892, 'epoch': 10.0})

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
finetuned_model_path = "./output/model/checkpoint-1750"

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(finetuned_model_path)

prompt = "A thrilling mystery novel about"
inputs = tokenizer(prompt, return_tensors="pt").to("cpu")

outputs = model.generate(
    inputs.input_ids,
    max_new_tokens=100,
    do_sample=True,
    top_k=50,
    top_p=0.95
)

output_string = tokenizer.batch_decode(outputs)

output_string
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ['A thrilling mystery novel about a young girl and her obsession with adventure, suspense, and violence; one of two masterpieces in the world of comic book fiction; and one of the most successful and influential comics ever. It is a novel of the mind at large. And it has earned the Academy Award.\nThe author of The Man in the White Stripes, Raymond K. Heinlein, is the author of "Universe #1 and #2." In addition to his work as the writer of "The Man in']
